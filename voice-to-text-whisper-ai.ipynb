# %%
from google.colab import drive
drive.mount("/content/drive",force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\kleme\Documents\Python Scripts\WhisperAI\voice-to-text-whisper-ai.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kleme/Documents/Python%20Scripts/WhisperAI/voice-to-text-whisper-ai.ipynb#Y110sZmlsZQ%3D%3D?line=0'>1</a> from google.colab import drive
#       <a href='vscode-notebook-cell:/c%3A/Users/kleme/Documents/Python%20Scripts/WhisperAI/voice-to-text-whisper-ai.ipynb#Y110sZmlsZQ%3D%3D?line=1'>2</a> drive.mount("/content/drive",force_remount=True)
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# # Install Whisper

# %% [markdown]
# 🔗 Links
# Google Colab | Free Version of Whisper - http://bit.ly/3Hpphi0
# Whisper Github - http://bit.ly/3HQgNlp
# Open AI Website - https://openai.com/

# %%
# install openai's whisper
# !pip install git+https://github.com/openai/whisper.git

# update the packages
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-kqnlptqd
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-kqnlptqd
#   Resolved https://github.com/openai/whisper.git to commit b91c907694f96a3fb9da03d4bbdc83fbcd3a40a4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# ...

# %% [markdown]
# ```
# # Isto está formatado como código
# ```
#
# #Upload .WAV/.MP3 file and change the directory, then run it 👌

# %%
#Import system io/s and WHISPER from OPEN AI
import os
import whisper

# %%
#CHOOSE THE FILES
#from google.colab import files
#uploaded = files.upload() #run this to get upload widget
# Out:
#      <input type="file" id="files-4b546e8e-5006-4c4f-8e51-b72ef8ceebf1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b546e8e-5006-4c4f-8e51-b72ef8ceebf1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import whisper
from whisper.tokenizer import LANGUAGES


# Parameters	English-only model	Multilingual model	Required VRAM	Relative speed

#model = whisper.load_model("tiny") #  39 M	tiny.en	tiny	~1 GB	~32x
#model = whisper.load_model("base") #  74 M	base.en	base	~1 GB	~16x
#model = whisper.load_model("small") ## load the small model       ~2 GB	~6x
#model = whisper.load_model("medium") # ~5 GB VRAM ~2x speed
model = whisper.load_model("large")  # ~10 GB
#nome do áudio com o formato mp3 ou wav
result = model.transcribe("audio_teste.unknown", language='pt', fp16=False, world_timestamps=True)
print(result["text"])

#def pegar_textos(result):
  #  return result.split(None, 1)[0]

#primeiros_nomes = map(pegar_textos, result)

#for result in primeiros_nomes:
 #   print(result)

#[print(result.text) for results in result]
#print(result.text)
# Out:
# 100%|█████████████████████████████████████| 2.87G/2.87G [00:49<00:00, 61.9MiB/s]
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/whisper/audio.py in load_audio(file, sr)
#      58     try:
# ---> 59         out = run(cmd, capture_output=True, check=True).stdout
#      60     except CalledProcessError as e:
#
# /usr/lib/python3.10/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     523         if check and retcode:
# --> 524             raise CalledProcessError(retcode, process.args,
#     525                                      output=stdout, stderr=stderr)
#
# CalledProcessError: Command '['ffmpeg', '-nostdin', '-threads', '0', '-i', 'audio_teste.unknown', '-f', 's16le', '-ac', '1', '-acodec', 'pcm_s16le', '-ar', '16000', '-']' returned non-zero exit status 1.
#
# ...

# %%
# Run Whisper AI:
##Trocar o nome do arquivo e o formato dele e idioma
#!whisper /content/untitled.wav --model medium.en
#!whisper /content/Whisper/audio_teste.unknown --model small.pt --output-txt --output-srt --output-file <nome-do-arquivo>
# !whisper /content/Whisper/audio_teste.unknown --model medium --language pt --max_line_width=2 --output-format:{txt,srt} --task:{trancribe,translate} --output-file audio_teste_shell

# %%
# Additional arguments:
# !whisper -h

# %% [markdown]
# #3.0 - Translation with Perfoming Python

# %%
# Load de the model
from whisper.tokenizer import LANGUAGES
model_medium = whisper.load_model("medium")

# load audio and pad/trim it to fit 30 seconds
audio = whisper.load_audio("content/Whisper/audio_teste.mp3") #path to file
audio = whisper.pad_or_trim(audio)

#make log-mel spectogram and move to the same device as the model
mel = whisper.log_mel_spectogram(audio).to(model.device)

# %% [markdown]
# #3.1 - Language Detection

# %%
# detect the spoken language
_,probs = model.detect_language(mel)
lang = max(probs, key=probs.get)
prob = "{0:.0%}".format(max(probs.values()))

#Print language that scored the higuest likihoood
print(f'Detected language (and Probability): {lang}', f'({prob})')

# %% [markdown]
# #3.2 - English or another to Pt Translation

# %%
# decode the audio
options= whisper.DecodingOptions(language='pt', task='translate', fp16=False, without_timestamps=False)
result = whisper.decode(model,mel,options)

# print the Result:
print(f'The text translation is: {result.text}')
